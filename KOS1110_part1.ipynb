# %% [markdown]
# <a href="https://colab.research.google.com/github/kbariyyah/Python-for-KOS1110/blob/master/KOS1110_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro to Python
#
# ---
# What is Python?
# * Python is an interpreted, high-level and general-purpose programming language.
# * Created by Guido van Rossum and first released in 1991.
# * Python's design philosophy emphasizes code readability with its notable use of significant whitespace.
# * Its language constructs and object-oriented approach aim to help programmers write clear, logical code for small and large-scale projects
# * Python available in Version 2.x and Version 3.X. For this course we'll use Python 3.
#
# Why Python?
# * Because it is free
# * Simple to learn - recommended for beginner.
# * Python works in any platform.
# * Various application such as Web development - Some of the globally known application such as YouTube, BitTorrent, DropBox, etc. use python to achieve their functionality.
# * Game development
# * Machine learning and AI
# * Data Science and visualisation etc.

# %% [markdown]
# # Python Environment
#
#
# *   Command prompt
# ![open-command-prompt-w10-5c19531146e0fb00013852e8.png](data:image/png;base64,...)
# *   Integrated Development Environment (IDE) and Python Editor - need to install e.g https://www.python.org/ and others
# ![Screen Shot 2020-11-16 at 7.10.51 AM.png](data:image/png;base64,...)
# *   Install Python complete package via Anaconda - https://docs.anaconda.com/anaconda/install/windows/ (Windows) and https://docs.anaconda.com/anaconda/install/mac-os/ (MacOS)
# *   Web browser - Jupyter Notebook https://jupyter.org/try , repl.it https://repl.it/, googlecolab , etc.

# %% [markdown]
# # Write your first Python Program called Hello World

# %%
#This first line is actually a comment. I does nothing
#This is my first Python program!
print ("Hello World")
# Out:
# Hello World

# %% [markdown]
# ##Exercise #1 write your first Python code

# %%
#The code above display the sentence the () bracket
#Now you can type your own code that will display the word I love icecream!!!
print ("")

# %%
#A comment in Python begin with a #
#Python does not execute a comment
#A comment is usually used to explain code
#Type another code below to print out Hi and then print your name on screen

# %%
#Any Python interpreter can be used as a calculator
4+5
# Out:
# 9

# %%
5**2
# Out:
# 25

# %% [markdown]
# # Arithmetic operations
# ---
# Numbers in python. There are two types of number in Python
# * integer : 3, 4, 1000, -3
# * decimals or floating point numbers :  2.5, 5.3 , -2.5
#
# Basic operations - addition (+), substraction (-), multiplication(*), exponentiation(***), division(/) and modulo (%).

# %%
# Arithmetic expressions - numbers, operators, expressions

print( 3, -1, 3.14159, -2.8)
# Out:
# 3 -1 3.14159 -2.8

# %%
# two corresponding data types int() and float()

print (type(3), type(3.14159))
print (type(3.0))
# Out:
# <class 'int'> <class 'float'>
# <class 'float'>

# %% [markdown]
# ### Data conversion

# %%
# we can convert between data types using int() and float()
# note that int() takes the "whole" part of a decimal number and doesn't round


print (int(3.84159), int(-2.8))
print (float(3), float(-1))
# Out:
# 3 -2
# 3.0 -1.0

# %%
# floating point number have around 15 decimal digits of accuracy
# pi is 3.1415926535897932384626433832795028841971...
# square root of two is 1.4142135623730950488016887242096980785696...

# approximation of pi, Python displays 15 decimal digits

print (3.1415926535897932384626433832795028841971)
# Out:
# 3.141592653589793

# %% [markdown]
# ### Operator precedence

# %%
# arithmetic operators
# +		plus		addition
# -		minus		subtraction
# *		times		multiplication
# /		divided by 	division
# **    power		exponentiation

print (1 + 2, 3 - 4, 5 * 6, 2 ** 3)
# Out:
# 3 -1 30 8

# %%
# Division in Python 3
# If one operand is a decimal, the answer is decimal

print (1.0 / 3)
print (1.0 / 3, 5.0 / 2.0, -7 / 3.0)
# Out:
# 0.3333333333333333
# 0.3333333333333333 2.5 -2.3333333333333335

# %%
# For multiplication, If both operands are ints, the answer is in decimal
print (1 / 3, 5 / 2, -7 / 3)

#include int identifier to convert the value into integer
print (int(1 / 3), int (5 / 2), int(-7 / 3))
# Out:
# 0.3333333333333333 2.5 -2.3333333333333335
# 0 2 -2

# %%
# expressions - number or a binary operator applied to two expressions
# minus is also a unary operator and can be applied to a single expression

print (1 + 2 * 3)
print ( 4.0 - 5.0 / 6.0)
print (7 * 8 + 9 * 10)
print (1 + 2 * 3, 4.0 - 5.0 / 6.0, 7 * 8 + 9 * 10)
# Out:
# 7
# 3.1666666666666665
# 146
# 7 3.1666666666666665 146

# %%
# expressions are entered as sequence of numbers and operations
# how are the number and operators grouped to form expressions?
# operator precedence - "please excuse my dear aunt sallie" = (), **, *, /, +,-

print (1 * 2 + 3 * 4)
print (2 + 12)
# Out:
# 14
# 14

# %%
# always manually group using parentheses when in doubt


print (1 * (2 + 3) * 4)
print (1 * 5 * 4)
# Out:
# 20
# 20

# %%
#This is great but not very interesting. 
#To do anything useful with data, we need to assign its value to a variable. I

# %% [markdown]
# # Variable in Python
#
#
#
# ---
# In Python, we can assign a value to a variable, using the equals sign =. For example, to assign value 60 to a variable weight_kg, we would execute
#
# ```weight_kg = 60 ```
#
# Naming convention
#
# *   Case sensitive - make sure you spell correctly when you call the variable in your program
# *   Cannot begin with numbers
# *   It is recommended to use one word, but
# *   If more than one word must separated by underscore
# *   Cannot use reserved words
#
# This means that, for example:
#
# *   ```weight0``` is a valid variable name, whereas ```0weight``` is not
# *    ```weight``` and ```Weight``` are different variables

# %%
# Variable assignment
b = 5
myname = 'Khairul Bariyyah'
my_var = 'Hello'
My_number = 7

# %%
# To display the value of a variable to the screen in Python, 
# we can use the print function.
print (b)
print (myname)
print (my_var)
print (my_var,myname)

b=10
print(b)
# Out:
# 5
# Khairul Bariyyah
# Hello
# Hello Khairul Bariyyah
# 10

# %% [markdown]
# # Function
# ---
# * Function - is a piece of code that you define, that you can execute later.
# * You only execute the code inside a function when you call that function.

# %%
# prints hello, world!
def hello():
  print("Hello World!")

# let's run (call ) our function
hello()# call to hello prints "Hello, world!"
h = hello()# call to hello prints "Hello, world!" a second time
print(h)# prints None since there was no return value
# Out:
# Hello World!
# Hello World!
# None

# %%
def hello():
  print("Hello World!")
  return 0
hello()# call to hello prints "Hello, world!"
h = hello()# call to hello prints "Hello, world!" a second time
print(h)# prints None since there was no return value
# Out:
# Hello World!
# Hello World!
# 0

# %%
# computes the area of a triangle
def triangle_area(base,height):# header - ends in colon
  area = (1/2) * base * height# body - all of body is indented
  #return area # body - return outputs value
  print ('The area of the triangle = ', area)

# %%
#call the function
triangle_area(7,8)
# Out:
# The area of the triangle =  28.0

# %%
# converts fahrenheit to celsius
def fahrenheit2celsius(fahrenheit):
  celsius = (5.0/9)*(fahrenheit - 32)
  return celsius

# %%
#call the function
# test!!!
c1 = fahrenheit2celsius(32)
c2 = fahrenheit2celsius(212)

print(c1, c2)
# Out:
# 0.0 100.0

# %% [markdown]
# ## Exercise #2
# Write a function to calculate sum of two numbers.
#
# **Hint!** Decide a name for your function and dont forget to call your function to see the output

# %%
#type your code here

# %% [markdown]
# ### Solution
#
# Click below for a solution.

# %%
def calculate_sum(num1,num2):
  ans = num1 + num2
  return ans

print(calculate_sum(10,20))
# Out:
# 30

# %% [markdown]
# ## Exercise #3
# Fix the error in the following function

# %%
def celsius_to_kelvin(temp_c)
return temp_c + 273.15

print(celsius_to_kelvin(0.))
# Out:
#   File "<ipython-input-27-ba581fa409ea>", line 1
#     def celsius_to_kelvin(temp_c)
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Solution

# %%
def celsius_to_kelvin(temp_c): #function definition must end with a semicolon
    return temp_c + 273.15 # body of function must be indented

print(celsius_to_kelvin(0.)) #call your function

# %% [markdown]
# # Python Data types
#
# Python knows various data types in Python. The most common ones are
# * Integer
# * Decimal or floating point numbers
# * String
# * List

# %% [markdown]
# ## String
#
# Python has a built-in string class named "str" with many handy
# String literals can be enclosed by either double or single quotes, although single quotes are more commonly used.
# Python strings are "immutable" which means they cannot be changed after they are created.
# Since strings can't be changed, we construct *new* strings as we go to represent computed values. So for example the expression ('hello' + 'there') takes in the 2 strings 'hello' and 'there' and builds a new string 'hellothere'.
#
# Since strings can't be changed, we construct *new* strings as we go to represent computed values. So for example the expression ('hello' + 'there') takes in the 2 strings 'hello' and 'there' and builds a new string 'hellothere'.
#
# Characters in a string can be accessed using the standard [ ] syntax, and like Java and C++, Python uses zero-based indexing, so if s is 'hello' s[1] is 'e'.
#
# The [ ] syntax and the len() function actually work on any sequence type -- strings, lists, etc..

# %%
s = 'hello there'
print(s[1])          ## e
print(len(s))       ## 4
print( s + ' there')  ## hello there
# Out:
# e
# 11
# hello there there

# %%
singlestr = "this is a string"

multistr = """It was the best of times.
It was the worst of times."""

print (singlestr)
print (multistr)
# Out:
# this is a string
# It was the best of times.
# It was the worst of times.

# %% [markdown]
# ## String method
#
# Here are some of the most common string methods. A method is like a function, but it runs "on" an object. If the variable s is a string, then the code s.lower() runs the lower() method on that string object and returns the result (this idea of a method running on an object is one of the basic ideas that make up Object Oriented Programming, OOP). Here are some of the most common string methods:
#
# * s.lower(), s.upper() -- returns the lowercase or uppercase version of the string
# * s.replace('old', 'new') -- returns a string where all occurrences of 'old' have been replaced by 'new'
# * s.split('delim') -- returns a list of substrings separated by the given delimiter. The delimiter is not a regular expression, it's just text. 'aaa,bbb,ccc'.split(',') -> ['aaa', 'bbb', 'ccc']. As a convenient special case s.split() (with no arguments) splits on all whitespace chars.
# * s.join(list) -- opposite of split(), joins the elements in the given list together using the string as the delimiter. e.g. '---'.join(['aaa', 'bbb', 'ccc']) -> aaa---bbb---ccc

# %%
print(s.upper())
print(s.lower())
print(s.split(' '))
print(s.replace("hello there", "hi there"))
print(s)
s.join('*****')
# Out:
# HELLO THERE
# hello there
# ['hello', 'there']
# hi there
# hello there
# '*hello there*hello there*hello there*hello there*'

# %% [markdown]
# ###String slices
#
# The "slice" syntax is a handy way to refer to sub-parts of sequences -- typically strings and lists. The slice s[start:end] is the elements beginning at start and extending up to but not including end. Suppose we have **s = "Hello"**
# ![Screen Shot 2020-11-15 at 3.03.23 PM.png](data:image/png;base64,...)

# %%
s[1:4] is 'ell' #-- chars starting at index 1 and extending up to but not including index 4
s[1:] is 'ello' #-- omitting either index defaults to the start or end of the string
s[:] is 'Hello' #-- omitting both always gives us a copy of the whole thing (this is the pythonic way to copy a sequence like a string or list)
s[1:100] is 'ello' #-- an index that is too big is truncated down to the string length

print(s[1:4])
print(s[1:])
print(s[:])
print(s[1:100])
# Out:
# ell
# ello there
# hello there
# ello there

# %%
#The standard zero-based index numbers give easy access to chars near the start of the string. As an alternative, Python uses negative numbers to give easy access to the chars at the end of the string: s[-1] is the last char 'o', s[-2] is 'l' the next-to-last char, and so on. Negative index numbers count back from the end of the string:

s[-1] is 'o' #-- last char (1st from the end)
s[-4] is 'e' #-- 4th from the end
s[:-3] is 'He' #-- going up to but not including the last 3 chars.
s[-3:] is 'llo' #-- starting with the 3rd char from the end and extending to the end of the string.

print (s[-1] )
print (s[-2] )
print (s[-3] )
print (s[-4] )
print (s[-5] )
# Out:
# e
# r
# e
# h
# t

# %% [markdown]
# ## String %
#
# Python has a formatted string facility to put together a string. The % operator takes a formatted string on the left (%d int, %s string, %f/%g floating point), and the matching values in a tuple on the right (a tuple is made of values separated by commas, typically grouped inside parentheses)

# %%
# % operator
text = "%d little monster come out, or one will %s, one will %s, and blow your %s down." % (3, 'huff', 'puff', 'house')
print(text)
# Out:
# 3 little monster come out, or one will huff, one will puff, and blow your house down.

# %% [markdown]
# ## String format
#
# To concatenate, or combine, two strings you can use the + operator.

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %% [markdown]
# ##Exercise #4
#
# Modify code above to add space between a and b

# %% [markdown]
# ### Solution

# %%
a = "Hello"
b = "World"
c = a + " " + b # modify this lines of code to add a space between a and b
print(c)
# Out:
# Hello World

# %% [markdown]
# ## List
#
# List is a Python Collection (Arrays)
#
# There are four collection data types in the Python programming language:
#
# * **List** is a collection which is ordered and changeable. Allows duplicate members.
# * **Tuple** is a collection which is ordered and unchangeable. Allows duplicate members.
# * **Set** is a collection which is unordered and unindexed. No duplicate members.
# * **Dictionary** is a collection which is unordered, changeable and indexed. No duplicate members.

# %% [markdown]
# ### Create a list

# %%
mylist = ["apple", "banana", "cherry"]

# %% [markdown]
# ### List
# List Items can be of any data type:

# %%
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]

# %%
## Access the first item in the list

print(list1[0]) #The first item has index 0.
# Out:
# apple

# %%
## change item in the list

thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrant"
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'cherry']

# %%
#Change the second value by replacing it with two new values:

thislist = ["apple", "banana", "cherry"]
thislist[1] = ["blackcurrant", "watermelon"]
print(thislist)
# Out:
# ['apple', ['blackcurrant', 'watermelon'], 'cherry']

# %%
#Insert "watermelon" as the third item:

thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print(thislist)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']

# %%
#The remove() method removes the specified item.

thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %% [markdown]
# ### Exercise #5
#
# Print the last item in list1

# %%
## Type your answer here

# %% [markdown]
# ### Solution

# %%
print(list1[-1]) ##The first item has index -1 or index 2
print(list1[2])
# Out:
# cherry
# cherry

# %% [markdown]
# # SUMMARY : Key points
#
#
# *  Basic data types in Python include integers, strings, and floating-point numbers (decimals).
#
# *  Use variable = value to assign a value to a variable in order to record it in memory.
#
# * Variables are created on demand whenever a value is assigned to them.
#
# * Variable name must follow naming convention
#
# * Use print(something) to display the value of something.
#
# * Use formatted string to incorporate other values (integer, string, float) from variables.
#
# * index can be used to access item in string or array (eg. list). Remember that the first item has index 0.
